# %% [markdown]
# # **Data Types & Structures Assignment**

# %% [markdown]
# **1. What are data structures, and why are they important?**
# - A data structure is a way of organizing and storing data in a computer so that it can be accessed and used efficiently.
# - they provide an organized framework for storing, retrieving, and manipulating data, which is fundamental to efficient programming and effective problem-solving. They enhance code performance, enable optimized memory usage, support code reusability, and are the backbone for complex systems like big data, AI, and operating systems.
#
# **2. Explain the difference between mutable and immutable data types with examples**
# - Mutable data types are those whose values can be modified in place after they are created.
# Examples: Lists, Dictionaries, Sets in Python.
# - Immutable data types are those whose values cannot be changed after they are created.
# Examples: Numbers (integers, floats), Strings, Tuples
#
# **3. What are the main differences between lists and tuples in Python?**
# - Lists are mutable and Tuples are immutable
# - Lists are defined using square brackets [] and Tuples are defined using parentheses ()
#
# **4. Describe how dictionaries store data**
# - Python dictionary is a data structure that stores the value in key: value pairs. Values in a dictionary can be of any data type and can be duplicated.
#
# **5. Why might you use a set instead of a list in Python**
# - Because sets cannot have multiple occurrences of the same element, it makes sets highly useful to efficiently remove duplicate values from a list or tuple and to perform common math operations like unions and intersections.
#
# **6. What is a string in Python, and how is it different from a list? **
# - In Python, a string is an immutable sequence of characters, used to represent text. Strings are enclosed in single quotes ('...'), double quotes ("..."), or triple quotes ("""...""" or '''...''') for multi-line strings.
# - i) List is mutable, whereas string is immutable. ii) String is specifically designed to store and manipulate textual data, and list can hold integers, floats, strings, other lists, or a mix of different types.
#
# **7  How do tuples ensure data integrity in Python?**
# - Tuples ensure data integrity primarily through their immutability. This means that once a tuple is created, its elements cannot be changed, added, or removed.
#
# **8 What is a hash table, and how does it relate to dictionaries in Python?**
# - A hash table is a data structure that implements an associative array abstract data type, which allows storing and retrieving data in key-value pairs.
# - Python's built-in dict type (dictionary) is implemented using hash tables. When you create a dictionary and add key-value pairs, Python internally uses a hash table to store this data.
#
# **9 Can lists contain different data types in Python?**
# - Yes, a Python list can contain elements of different data types.
#
# **10 Explain why strings are immutable in Python**
# - Once a string object is created, its content cannot be changed. Any operation that appears to modify a string, such as concatenation or replacing a character, actually results in the creation of a new string object in memory. The original string object remains unchanged.
#
# **11 What advantages do dictionaries offer over lists for certain tasks?**
# - Dictionaries offer significant advantages over lists for tasks that involve fast lookups, associative data, and enhanced code readability. While lists are ordered collections accessed by a numeric index, dictionaries store data in unordered key-value pairs, using a hash table for efficient retrieval.
#
# **12 Describe a scenario where using a tuple would be preferable over a list**
# - You should prefer tuples when you need an immutable sequence, such as function return values or constant data. eg. Employee ID, or Aadhar number
#
# **13 How do sets handle duplicate values in Python?**
# - sets are designed to store only unique elements, meaning they inherently do not allow duplicate values. When you attempt to add an element that is already present in a set, the set will simply ignore the addition and remain unchanged. The duplicate element will not be added, and no error will be raised.
#
# **14 How does the “in” keyword work differently for lists and dictionaries?**
# - The in operator tests for value equality. It returns True if the values are equal, even if their types are different.
# - 'in' for lists checks for the presence of a value and 'in' for dictionaries checks for the presence of a key.
#
# **15 Can you modify the elements of a tuple? Explain why or why not.**
# - No. Tuples in Python are immutable, meaning their elements cannot be directly modified, added, or removed after the tuple has been created.
#
# **16 What is a nested dictionary, and give an example of its use case?**
# - A nested dictionary is a dictionary where the values associated with one or more keys are themselves other dictionaries. This structure allows for the representation of hierarchical or complex data in a structured manner.
# - for example: An employee database where you need to store information about multiple employees, and each employee has several attributes
#
# **17 Describe the time complexity of accessing elements in a dictionary.**
# - It is on average, the time taken to retrieve an element from a dictionary is constant and does not depend on the size of the dictionary.
#
# **18 In what situations are lists preferred over dictionaries?**
# - when you need an ordered, sequential collection of items, including duplicates, and are primarily accessing data by its numeric index.
#
# **19 Why are dictionaries considered unordered, and how does that affect data retrieval?**
# - Dictionary's primary purpose is fast, key-based access, not maintaining the order of insertion or any other sequence. This unordered nature means you cannot rely on a specific sequence when iterating or printing items, and data retrieval is always based on the unique key, not a positional index.
#
# **20 Explain the difference between a list and a dictionary in terms of data retrieval.**
# - Lists are ordered collections of items, where each item is assigned a numerical index starting from 0.Data retrieval in a list is primarily done by index. To access an element, its position within the sequence (its index) must be known.
# - Dictionaries are unordered collections of key-value pairs. Each value is associated with a unique, immutable key. Data retrieval in a dictionary is done by key. To access a value, its corresponding key must be known.

# %%
# 1 Write a code to create a string with your name and print it.
my_name = "Santosh"
print(my_name)
# Out:
# Santosh

# %%
# 2 Write a code to find the length of the string "Hello World"
length= len("Hello World")
print("Length of the string:", length)
# Out:
# Length of the string: 11

# %%
#3 Write a code to slice the first 3 characters from the string "Python Programming"
String = "Python Programming"
print(String[:3])
# Out:
# Pyt

# %%
#4 Write a code to convert the string "hello" to uppercase
String = "hello"
Ustring=String.upper()
Ustring
# Out:
# 'HELLO'

# %%
#5 Write a code to replace the word "apple" with "orange" in the string "I like apple"
my_string = "I like apple"
new_string = my_string.replace("apple", "orange")
new_string
# Out:
# 'I like orange'

# %%
#6 Write a code to create a list with numbers 1 to 5 and print it.
my_list = [1, 2, 3, 4, 5]
print(my_list)
# Out:
# [1, 2, 3, 4, 5]

# %%
#7 Write a code to append the number 10 to the list [1, 2, 3, 4]
my_list = [1, 2, 3, 4]
my_list.append(10)
my_list
# Out:
# [1, 2, 3, 4, 10]

# %%
#8 Write a code to remove the number 3 from the list [1, 2, 3, 4, 5]
my_list = [1, 2, 3, 4, 5]
my_list.remove(3)
my_list
# Out:
# [1, 2, 4, 5]

# %%
#9 Write a code to access the second element in the list ['a', 'b', 'c', 'd']
EleList = ['a', 'b', 'c', 'd']
EleList[1]
# Out:
# 'b'

# %%
#10 Write a code to reverse the list [10, 20, 30, 40, 50]
Num_list=[10, 20, 30, 40, 50]
reversed_list = Num_list[::-1]
print(reversed_list)
# Out:
# [50, 40, 30, 20, 10]

# %%
# 11 Write a code to create a tuple with the elements 100, 200, 300 and print it
my_tuple = (100, 200, 300)
print(my_tuple)
# Out:
# (100, 200, 300)

# %%
#12 Write a code to access the second-to-last element of the tuple ('red', 'green', 'blue', 'yellow')
Colors = ('red', 'green', 'blue', 'yellow')
second_to_last = Colors[-2]
print(second_to_last)
# Out:
# blue

# %%
# 13 Write a code to find the minimum number in the tuple (10, 20, 5, 15)
NumTuple = (10, 20, 5, 15)
minimum = min(NumTuple)
print("Minimum number:", minimum)
# Out:
# Minimum number: 5

# %%
#14 Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit')
Animals = ('dog', 'cat', 'rabbit')
index_cat = Animals.index("cat")
print("Index of cat:", index_cat)
# Out:
# Index of cat: 1

# %%
#15  Write a code to create a tuple containing three different fruits and check if "kiwi" is in it
fruitsTup = ("mango", "banana","kiwi")
if "kiwi" in fruitsTup:
    print("Yes, kiwi is there.")
else:
    print("No, kiwi is not there.")
# Out:
# Yes, kiwi is there.

# %%
#16  Write a code to create a set with the elements 'a', 'b', 'c' and print it.
New_set = {'a', 'b', 'c'}
print(New_set)
# Out:
# {'c', 'b', 'a'}

# %%
#17 Write a code to clear all elements from the set {1, 2, 3, 4, 5}
new_set={1, 2, 3, 4, 5}
new_set.clear()
print(new_set)
# Out:
# set()

# %%
#18 Write a code to remove the element 4 from the set {1, 2, 3, 4}
my_set={1, 2, 3, 4}
my_set.remove(4)
print(my_set)
# Out:
# {1, 2, 3}

# %%
#19 Write a code to find the union of two sets {1, 2, 3} and {3, 4, 5}
S1 = {1, 2, 3}
S2 = {3, 4, 5}

# Method using union()
union_set = S1.union(S2)
print("Union with union(): ", union_set)

# Method using | operator
union_set2 = S1 | S2
print("Union using | operator: ", union_set)
# Out:
# Union with union():  {1, 2, 3, 4, 5}
# Union using | operator:  {1, 2, 3, 4, 5}

# %%
#20 Write a code to find the intersection of two sets {1, 2, 3} and {2, 3, 4}
S1 = {1, 2, 3}
S2 = {3, 4, 5}

# Method using intersection()
IntSec_set = S1.intersection(S2)
print("intersection with intersection(): ", IntSec_set)

# Method using & operator
IntSec_set = S1 & S2
print("intersection using & operator: ", IntSec_set)
# Out:
# intersection with intersection():  {3}
# intersection using & operator:  {3}

# %%
#21  Write a code to create a dictionary with the keys "name", "age", and "city", and print it.
my_dict = {"name": "Santosh", "age": 40,"city": "Navi Mumbai"}
print(my_dict)
# Out:
# {'name': 'Santosh', 'age': 40, 'city': 'Navi Mumbai'}

# %%
#22 Write a code to add a new key-value pair "country": "USA" to the dictionary {'name': 'John', 'age': 25}
Info_dict={'name': 'John', 'age': 25}
Info_dict['country']='USA'
print(Info_dict)
# Out:
# {'name': 'John', 'age': 25, 'country': 'USA'}

# %%
#23 Write a code to access the value associated with the key "name" in the dictionary {'name': 'Alice', 'age': 30}
my_dict = {'name': 'Alice', 'age': 30}
name_value = my_dict['name']
print(name_value)
# Out:
# Alice

# %%
#24 Write a code to remove the key "age" from the dictionary {'name': 'Bob', 'age': 22, 'city': 'New York'}
my_dict = {'name': 'Bob', 'age': 22, 'city': 'New York'}
my_dict.pop('age')
print(my_dict)
# Out:
# {'name': 'Bob', 'city': 'New York'}

# %%
#25 Write a code to check if the key "city" exists in the dictionary {'name': 'Alice', 'city': 'Paris'}
my_dict ={'name': 'Alice', 'city': 'Paris'}
if 'city' in my_dict:
    print("Key 'city' exists in the dictionary")
else:
    print("Key 'city' does not exist in the dictionary")
# Out:
# Key 'city' exists in the dictionary

# %%
#26 Write a code to create a list, a tuple, and a dictionary, and print them all.
lst = ['s', 2, 3, 4, 5, 6]
tpl = ('m', 'd', 'c')
dict = {'name': 'Alice', 'age': 30}

print("List:", lst)
print("Tuple:", tpl)
print("Dictionary:", dict)
# Out:
# List: ['s', 2, 3, 4, 5, 6]
# Tuple: ('m', 'd', 'c')
# Dictionary: {'name': 'Alice', 'age': 30}

# %%
#27 Write a code to create a list of 5 random numbers between 1 and 100, sort it in ascending order, and print the result.(replaced)
import random
random_numbers = []
for i in range(5):
    num = random.randint(1, 100)  # generate a random number
    random_numbers.append(num)
print("original elements of List:", random_numbers)
random_numbers.sort()
print("Sorted random numbers:", random_numbers)
# Out:
# original elements of List: [91, 15, 12, 9, 72]
# Sorted random numbers: [9, 12, 15, 72, 91]

# %%
#28 Write a code to create a list with strings and print the element at the third index.
my_list = ["cherry", "water", "banana","cake" , "date", "guava"]

# Access the element at index 3
Third_index = my_list[3]

# Print the element
print("element at index 3:", Third_index)
# Out:
# element at index 3: cake

# %%
# 29 Write a code to combine two dictionaries into one and print the result.
d1 = {'name': 'Santosh', 'age': 5}
d2 = {'capital': 'London', 'country': 'UK'}
d3=d1.copy()
d3.update(d2)
print(d3)
# Out:
# {'name': 'Santosh', 'age': 5, 'capital': 'London', 'country': 'UK'}

# %%
# 30  Write a code to convert a list of strings into a set.
lst = ["toy", "boy", "roy", "boy", "toy"]
st=set(lst)
st
# Out:
# {'boy', 'roy', 'toy'}
